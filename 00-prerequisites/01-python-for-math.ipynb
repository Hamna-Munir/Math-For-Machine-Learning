# %% [markdown]
# # Python for Mathematical Computing
# ---
# **Author:** Hamna Munir
# **Repository:** Math-for-Machine-Learning
# **Notebook:** 01-python-for-math.ipynb
#
# **Goal:** Build a strong foundation in Python for mathematical operations used in Machine Learning.
# ---

# %% [markdown]
# ## 📌 Concept
# Python is the primary programming language used in Machine Learning. It provides simple syntax and powerful libraries that allow us to perform mathematical computations efficiently.

# %% [markdown]
# ## 📌 Mathematical Explanation
# Mathematical operations such as addition, subtraction, multiplication, division, and exponentiation are the building blocks of Machine Learning. These operations are used in loss functions, gradients, optimizers, and matrix computations.

# %% [markdown]
# ### Basic Mathematical Operations in Python

# %%
a = 10
b = 3

addition = a + b
subtraction = a - b
multiplication = a * b
division = a / b
power = a ** b

addition, subtraction, multiplication, division, power
# Out:
# (13, 7, 30, 3.3333333333333335, 1000)

# %% [markdown]
# ## 📌 Visualization
# Visualizing a simple mathematical function helps in understanding how models learn patterns from data.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
y = x ** 2

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('y = x²')
plt.show()

# %% [markdown]
# ## 📌 Python Code
# Python allows clean and readable mathematical expressions, which makes experimentation and debugging easier.

# %%
numbers = [1, 2, 3, 4, 5]
squared = [n ** 2 for n in numbers]
print("Squared Values:", squared)
# Out:
# Squared Values: [ 1  4  9 16 25]

# %% [markdown]
# ## 📌 ML Connection
# Every Machine Learning algorithm relies on mathematical computations. Python enables these operations through libraries like NumPy, which power linear regression, neural networks, and optimization algorithms.

# %% [markdown]
# ## 📌 Summary
# - Python is the foundation of Machine Learning programming
# - Mathematical operations are central to ML algorithms
# - Visualization improves mathematical intuition
# - Clean Python code leads to better ML implementations
#
# **Developed by — Hamna Munir 🌱**
# ---
