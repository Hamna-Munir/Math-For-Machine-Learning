# %% [markdown]
# # Linear Regression From Scratch
# ---
# **Author:** Hamna Munir
# **Repository:** Math-for-Machine-Learning
# **Section:** 08-ML-Math-Case-Studies
#
# **Goal:** Understand linear regression mathematically and implement it from scratch in Python.
#
# ---

# %% [markdown]
# ## Introduction
#
# Linear Regression is a fundamental algorithm in machine learning for predicting a continuous target variable using linear relationships between input features and the target.
#
# Equation:
# \( y = X\beta + \epsilon \)
# Where:
# - \(y\) = target vector
# - \(X\) = feature matrix
# - \(\beta\) = coefficients
# - \(\epsilon\) = error term

# %% [markdown]
# ## Generate Sample Data
# We'll generate synthetic data to test our implementation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %% [markdown]
# ## Ordinary Least Squares (OLS)
# The goal is to minimize the Mean Squared Error (MSE):
#
# MSE = 1/n * Σ(y_i - ŷ_i)²
#
# Normal Equation:
# \( \beta = (X^T X)^{-1} X^T y \)

# %%
# Add bias term (column of ones)
X_b = np.c_[np.ones((100, 1)), X]

# Compute theta (coefficients)
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
theta_best

# %% [markdown]
# ## Predictions
# We can predict new values using the learned coefficients.

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]
y_predict = X_new_b.dot(theta_best)
y_predict

# %% [markdown]
# ## Visualization
# Plot the data points and regression line.

# %%
plt.scatter(X, y)
plt.plot(X_new, y_predict, "r-", label="Regression Line")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# %% [markdown]
# ## Gradient Descent (Optional)
# Instead of the normal equation, we can use gradient descent to iteratively update coefficients:
#
# \( \theta = \theta - \alpha \nabla_\theta MSE \)

# %% [markdown]
# ## Conclusion
# - Implementing Linear Regression from scratch helps understand the math behind it.
# - Knowledge of OLS and gradient descent is foundational for more complex models.
# - This implementation can be extended to regularized regression (Ridge, Lasso).
