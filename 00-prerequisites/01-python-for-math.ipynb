# %% [markdown]
# # Python for Math
#
#  **Concept**
# Using Python as a tool for mathematical computation in Machine Learning.

# %% [markdown]
#  **Mathematical Explanation**
# Basic mathematical operations such as addition, multiplication, division, and exponentiation form the foundation of ML computations.

# %%
a = 10
b = 3

a + b, a - b, a * b, a / b, a ** b
# Out:
# (13, 7, 30, 3.3333333333333335, 1000)

# %% [markdown]
#  **ML Connection**
# All ML models rely on numerical computations implemented efficiently using Python and NumPy.

# %% [markdown]
#  **Summary**
# - Python is essential for ML math
# - Mathematical operations form ML foundations
# - Clean code improves model understanding
#
# **Developed by — Hamna Munir **
