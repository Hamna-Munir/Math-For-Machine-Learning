# %% [markdown]
# # Gradient Descent Visualization
# ---
# **Author:** Hamna Munir
# **Repository:** ML-from-Scratch
# **Goal:** Visualize gradient descent on a simple function
#
# ---

# %% [markdown]
# ## Introduction
#
# Gradient Descent is an optimization algorithm used to minimize a function by iteratively moving in the direction of the steepest descent (negative gradient).

# %% [markdown]
# We'll use a **2D quadratic function** for easy visualization:
#
# f(x, y) = x² + y²
#
# The global minimum is at (0,0).

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Define Function and Gradient
#
# f(x, y) = x² + y²
# Gradient: ∇f = [2x, 2y]

# %%
def f(X):
    return X[0]**2 + X[1]**2

def grad_f(X):
    return np.array([2*X[0], 2*X[1]])

# %% [markdown]
# ## Gradient Descent Function

# %%
def gradient_descent(start, lr, iterations):
    path = [start]
    x = np.array(start, dtype=float)
    for i in range(iterations):
        grad = grad_f(x)
        x = x - lr * grad
        path.append(x.copy())
    return np.array(path)

# %% [markdown]
# ## Run Gradient Descent

# %%
start = [4, 4]
learning_rate = 0.1
iterations = 20

path = gradient_descent(start, learning_rate, iterations)
path
# Out:
# array([[4.        , 4.        ],
#        [3.2       , 3.2       ],
#        [2.56      , 2.56      ],
#        [2.048     , 2.048     ],
#        [1.6384    , 1.6384    ],
#        [1.31072   , 1.31072   ],
#        [1.048576  , 1.048576  ],
#        [0.8388608 , 0.8388608 ],
#        [0.67108864, 0.67108864],
#        [0.53687091, 0.53687091],
#        [0.42949673, 0.42949673],
#        [0.34359738, 0.34359738],
#        [0.27487791, 0.27487791],
#        [0.21990233, 0.21990233],
#        [0.17592186, 0.17592186],
#        [0.14073749, 0.14073749],
#        [0.11258999, 0.11258999],
#        [0.09007199, 0.09007199],
#        [0.07205759, 0.07205759],
#        [0.05764608, 0.05764608],
#        [0.04611686, 0.04611686]])

# %% [markdown]
# ## 2D Contour Visualization

# %%
# Create a grid for contour plot
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

plt.figure(figsize=(8,6))
plt.contour(X, Y, Z, levels=30, cmap='viridis')
plt.plot(path[:,0], path[:,1], 'ro-', label='Gradient Descent Path')
plt.scatter([0], [0], color='blue', label='Minimum')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gradient Descent on f(x, y) = x^2 + y^2')
plt.legend()
plt.show()

# %% [markdown]
# ## 3D Surface Visualization

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.8)
ax.plot(path[:,0], path[:,1], np.array([f(p) for p in path]), 'r.-', label='GD Path')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
ax.set_title('Gradient Descent Path on 3D Surface')
plt.show()

# %% [markdown]
# ### Experiment:
# - Try changing the **learning rate** to see how the path changes.
# - Too high → overshoot, too low → slow convergence.
