# %% [markdown]
# # PCA (Principal Component Analysis) From Scratch
# ---
# **Author:** Hamna Munir
# **Repository:** Math-for-Machine-Learning
# **Section:** 08-ML-Math-Case-Studies
#
# **Goal:** Understand PCA mathematically and implement it from scratch using NumPy.
#
# ---

# %% [markdown]
# ## Introduction
#
# Principal Component Analysis (PCA) is a **dimensionality reduction technique** used to transform data into a lower-dimensional space while preserving as much variance as possible.
#
# Key ideas:
# - Reduce number of features
# - Preserve maximum variance
# - Remove redundancy in data

# %% [markdown]
# ## Steps in PCA
#
# 1. Standardize the data
# 2. Compute covariance matrix
# 3. Compute eigenvalues and eigenvectors
# 4. Sort eigenvectors by eigenvalues
# 5. Project data onto principal components

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generate Sample Data

# %%
np.random.seed(42)

# Create correlated data
mean = [0, 0]
cov = [[3, 2], [2, 2]]
X = np.random.multivariate_normal(mean, cov, 200)

# %% [markdown]
# ## Visualize Original Data

# %%
plt.scatter(X[:,0], X[:,1], alpha=0.6)
plt.title("Original Data")
plt.xlabel("X1")
plt.ylabel("X2")
plt.show()

# %% [markdown]
# ## Step 1: Standardize Data

# %%
X_mean = np.mean(X, axis=0)
X_centered = X - X_mean

# %% [markdown]
# ## Step 2: Covariance Matrix

# %%
cov_matrix = np.cov(X_centered.T)
cov_matrix
# Out:
# array([[2.7186379 , 1.84079041],
#        [1.84079041, 1.87427921]])

# %% [markdown]
# ## Step 3: Eigenvalues and Eigenvectors

# %%
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

eigenvalues, eigenvectors
# Out:
# (array([4.18504129, 0.40787583]),
#  array([[ 0.78215821, -0.62307987],
#         [ 0.62307987,  0.78215821]]))

# %% [markdown]
# ## Step 4: Sort Eigenvectors

# %%
idx = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[idx]
eigenvectors = eigenvectors[:, idx]

# %% [markdown]
# ## Step 5: Project Data

# %%
# Choose top 1 principal component
k = 1
W = eigenvectors[:, :k]

X_reduced = X_centered.dot(W)

# %% [markdown]
# ## Visualize Reduced Data

# %%
plt.scatter(X_reduced, np.zeros_like(X_reduced), alpha=0.6)
plt.title("1D Projection using PCA")
plt.xlabel("Principal Component 1")
plt.show()

# %% [markdown]
# ## Explained Variance

# %%
explained_variance_ratio = eigenvalues / np.sum(eigenvalues)
explained_variance_ratio
# Out:
# array([0.9111946, 0.0888054])

# %% [markdown]
# ## Conclusion
#
# - PCA reduces dimensionality while preserving variance.
# - Eigenvectors define new feature space.
# - Eigenvalues show importance of each component.
# - Widely used in data preprocessing, visualization, and noise reduction.
