# %% [markdown]
# # Probability Basics
# ---
# **Author:** Hamna Munir
# **Repository:** Math-for-Machine-Learning
# **Section:** Probability
#
# **Goal:** Understand the fundamentals of probability and uncertainty used in Machine Learning.
#
# ---

# %% [markdown]
# ## Introduction
#
# Probability measures the likelihood that an event will occur.
#
# In Machine Learning, probability helps models deal with **uncertainty, noise, and predictions**.
#
# Examples:
#
# - Spam detection
# - Medical diagnosis
# - Recommendation systems
# - Risk prediction

# %% [markdown]
# ## Key Concepts
#
# **Experiment** – A process that produces outcomes.
#
# **Outcome** – A possible result of an experiment.
#
# **Sample Space (S)** – Set of all possible outcomes.
#
# **Event** – A subset of the sample space.

# %% [markdown]
# ### Example
#
# Tossing a coin:
#
# Sample Space:
#
# S = {Heads, Tails}
#
# Event:
#
# A = Getting Heads

# %% [markdown]
# ## Probability Formula
#
# If all outcomes are equally likely:
#
# P(A) = Number of favorable outcomes / Total outcomes
#
# Properties:
#
# - 0 ≤ P(A) ≤ 1
# - P(S) = 1
# - P(∅) = 0

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Coin Toss Simulation
#
# Let's simulate a coin toss experiment using Python.

# %%
tosses = 1000

results = [random.choice(['H', 'T']) for _ in range(tosses)]

heads = results.count('H')
tails = results.count('T')

print('Heads:', heads)
print('Tails:', tails)
# Out:
# Heads: 507
# Tails: 493

# %% [markdown]
# ## Empirical Probability
#
# Empirical probability is calculated from experimental results.
#
# P(A) = Number of times event A occurs / Total trials

# %%
p_heads = heads / tosses
p_tails = tails / tosses

print('P(Heads) ≈', p_heads)
print('P(Tails) ≈', p_tails)
# Out:
# P(Heads) ≈ 0.507
# P(Tails) ≈ 0.493

# %% [markdown]
# ## Visualization
#
# Visualizing the probability results.

# %%
labels = ['Heads', 'Tails']
values = [heads, tails]

plt.bar(labels, values)
plt.title('Coin Toss Outcomes')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Why Probability Matters in Machine Learning
#
# Probability is the foundation of many ML algorithms.
#
# Examples:
#
# - Naive Bayes classifier
# - Bayesian Networks
# - Probabilistic graphical models
# - Uncertainty estimation in predictions
#
# Understanding probability helps us build models that can reason under uncertainty.

# %% [markdown]
# ## Summary
#
# In this notebook we learned:
#
# - Basic probability concepts
# - Sample space and events
# - Probability formula
# - Simulation of random experiments
# - Importance of probability in Machine Learning
